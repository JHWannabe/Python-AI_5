# %% [markdown]
# # 1. Albumentations
# * https://github.com/albumentations-team/albumentations
# * 이미지를 쉽게 augmentation 해주는 파이썬 라이브러리
# * 다양한 영상변환 알고리즘을 제공하고 있고, 처리속도도 매우 빨라 딥러닝 전처리용으로 많이 사용됨

# %%
# !pip install albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-1.1.0-py3-none-any.whl (102 kB)
# Collecting scikit-image>=0.16.1
#   Downloading scikit_image-0.19.2-cp38-cp38-win_amd64.whl (12.6 MB)
# Collecting qudida>=0.0.4
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from albumentations) (1.22.2)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp38-cp38-win_amd64.whl (155 kB)
# Collecting opencv-python-headless>=4.1.1
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-win_amd64.whl (35.3 MB)
# Requirement already satisfied: scipy in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from albumentations) (1.8.0)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.16.1-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.16.1->albumentations) (9.0.1)
# Collecting networkx>=2.2
#   Downloading networkx-2.7.1-py3-none-any.whl (2.0 MB)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.2.0-cp38-cp38-win_amd64.whl (4.2 MB)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.2.9-py3-none-any.whl (180 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.16.1->albumentations) (21.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from qudida>=0.0.4->albumentations) (1.0.2)
# Requirement already satisfied: typing-extensions in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from qudida>=0.0.4->albumentations) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from packaging>=20.0->scikit-image>=0.16.1->albumentations) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\jhjun\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.1.0)
# Installing collected packages: imageio, networkx, PyWavelets, tifffile, scikit-image, opencv-python-headless, qudida, PyYAML, albumentations
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] 액세스가 거부되었습니다: 'c:\\users\\jhjun\\appdata\\local\\programs\\python\\python38\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\jhjun\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
